# %% [markdown]
# # Installation & First Crew
#
# This notebook accompanies the [Agent Foundry](https://agent-foundry-theta.vercel.app) CrewAI roadmap.
#
# You will install CrewAI, set up your API key, and run your first multi-agent crew.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key
#
# Enter your OpenAI API key when prompted. The key is not stored or displayed.

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Define Agents
#
# We create two agents with distinct roles:
# - A **Researcher** who finds information
# - A **Writer** who crafts content from the research

# %%
from crewai import Agent, Task, Crew

researcher = Agent(
    role="AI Researcher",
    goal="Find the latest trends in AI agents",
    backstory="You are an expert AI researcher who stays current with the latest developments in autonomous agents and multi-agent systems.",
    verbose=True,
)

writer = Agent(
    role="Technical Writer",
    goal="Write clear, engaging summaries of technical topics",
    backstory="You are a skilled technical writer who makes complex AI topics accessible to developers.",
    verbose=True,
)

# %% [markdown]
# ## 4. Define Tasks
#
# Each task has a description, expected output, and is assigned to an agent.

# %%
research_task = Task(
    description="Research the top 3 trends in AI agents for 2025. Focus on practical applications.",
    expected_output="A bullet-point list of 3 trends with a one-paragraph explanation each.",
    agent=researcher,
)

write_task = Task(
    description="Write a short blog post summarizing the research findings.",
    expected_output="A 300-word blog post with an introduction, 3 sections (one per trend), and a conclusion.",
    agent=writer,
)

# %% [markdown]
# ## 5. Assemble and Run the Crew
#
# The crew links agents to tasks and executes them in sequence.

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    verbose=True,
)

result = crew.kickoff()
print(result)

# %% [markdown]
# ## What Just Happened?
#
# 1. Two **agents** were created with distinct roles and goals
# 2. Two **tasks** were defined with clear expected outputs
# 3. A **crew** was assembled, linking agents to tasks
# 4. `crew.kickoff()` executed the tasks in sequential order
#
# The researcher gathered information first, then the writer produced a polished blog post using those findings.
