# %% [markdown]
# # Problem 61: Input Sanitizer
#
# **Difficulty:** Easy | **Framework:** OpenAI Agents SDK
#
# **Categories:** guardrails
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/input-sanitizer).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q openai-agents

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - You must sanitize input before it reaches the LLM
# - The agent must still process the cleaned version of the user's request
# - Do not reject messages outright — strip dangerous content and proceed

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from agents import Agent, Runner

agent = Agent(
    name="Support Assistant",
    instructions="You are a helpful customer support assistant.",
)

# BUG: Raw user input with HTML/script tags is passed directly to the agent
user_input = 'Hello <script>alert("xss")</script> can you help me?'

result = Runner.run_sync(agent, user_input)
print(result.final_output)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Use a regular expression or an HTML parsing library to strip tags from the input
# 2. Apply sanitization as a preprocessing step before passing input to the agent
# 3. Consider edge cases like nested tags, encoded entities, and script attributes

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - HTML and script tags are stripped
# - Legitimate message content preserved
# - Agent still responds helpfully
