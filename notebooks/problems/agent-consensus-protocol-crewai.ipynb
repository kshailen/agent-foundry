# %% [markdown]
# # Problem 86: Agent Consensus Protocol
#
# **Difficulty:** Hard | **Framework:** CrewAI
#
# **Categories:** multi-agent
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/agent-consensus-protocol).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - At least three agents must independently produce an answer
# - A voting or consensus mechanism must determine the final answer
# - The system must handle disagreements (no unanimous requirement)
# - The first agent's answer must not be automatically preferred

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from crewai import Agent, Task, Crew, Process
from crewai import LLM

llm = LLM(model="gpt-4o-mini")

# BUG: Only one agent answers — its response is always used with no validation
# TODO: Add multiple agents and a consensus/voting mechanism
fact_checker = Agent(
    role="Fact Checker",
    goal="Verify factual claims and provide accurate answers",
    backstory="You are a careful fact-checker who validates information.",
    llm=llm,
)

verify_task = Task(
    description="Is the following claim true or false? Provide your answer and reasoning. Claim: '{claim}'",
    expected_output="TRUE or FALSE with a brief explanation",
    agent=fact_checker,
)

crew = Crew(
    agents=[fact_checker],
    tasks=[verify_task],
    process=Process.sequential,
)

result = crew.kickoff(inputs={"claim": "The Great Wall of China is visible from space with the naked eye"})
print(result)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Have each agent produce an answer independently, then collect all answers for voting
# 2. Use a majority-vote approach or a mediator agent that weighs each answer
# 3. In LangGraph, run agent nodes in parallel (or sequentially) then aggregate in a consensus node

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Multiple agents produce answers
# - Voting or consensus mechanism
# - Handles disagreements
# - No first-agent bias
