# %% [markdown]
# # Problem 63: Output Length Limiter
#
# **Difficulty:** Easy | **Framework:** CrewAI
#
# **Categories:** guardrails, cost-optimization
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/output-length-limiter).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - You must cap the agent's output to a reasonable length (e.g. 200 words or 800 characters)
# - The truncation must not cut mid-sentence if possible
# - The agent should still provide a complete, useful answer within the limit

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from crewai import Agent, Task, Crew

# BUG: No length constraints — the agent writes 2000-word essays
explainer = Agent(
    role="Explainer",
    goal="Provide thorough, detailed answers to any question",
    backstory="You are a helpful assistant who explains concepts in detail.",
)

task = Task(
    description="Explain how neural networks work",
    expected_output="A thorough explanation of neural networks",
    agent=explainer,
)

crew = Crew(agents=[explainer], tasks=[task])
result = crew.kickoff()
print(result)
print(f"\n--- Output length: {len(str(result).split())} words ---")

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. A post-processing step can truncate or summarize the output after the agent responds
# 2. Alternatively, add explicit length instructions to the system prompt
# 3. Combining prompt-level guidance with a hard truncation fallback gives the best results

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Output is within length limit
# - No mid-sentence cutoff
# - Response is still useful
# - Token usage reduced
