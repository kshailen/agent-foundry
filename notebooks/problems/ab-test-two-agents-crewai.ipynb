# %% [markdown]
# # Problem 102: A/B Test Two Agents
#
# **Difficulty:** Hard | **Framework:** CrewAI
#
# **Categories:** evaluation, cost-optimization
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/ab-test-two-agents).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - Both agent configurations must run on the same set of test inputs for fair comparison
# - Each configuration must be scored on quality (accuracy) and cost (tokens/dollars)
# - The comparison must produce a winner recommendation with statistical justification
# - The framework must support swapping in new configurations without code changes

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from crewai import Agent, Task, Crew, Process
from crewai import LLM

llm = LLM(model="gpt-4o")

# BUG: Only one agent configuration — no way to compare alternatives
# TODO: Run two configs side-by-side and compare quality vs cost
support_agent = Agent(
    role="Customer Support",
    goal="Answer customer questions thoroughly and professionally",
    backstory="You are a helpful customer support agent.",
    llm=llm,
)

test_queries = [
    "What is your return policy?",
    "My order arrived damaged, what should I do?",
    "Can I change my shipping address after placing an order?",
    "Do you price match with competitors?",
    "How do I cancel my subscription?",
]
for q in test_queries:
    task = Task(description=q, expected_output="A helpful response", agent=support_agent)
    crew = Crew(agents=[support_agent], tasks=[task], process=Process.sequential)
    result = crew.kickoff()
    print(f"Q: {q}\nA: {str(result)[:100]}...\n")

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Run both agents on the same inputs and use an LLM-as-judge to score quality on a 1-5 scale for each response pair
# 2. Track token usage and compute cost per query for each configuration using API response metadata
# 3. Calculate a cost-effectiveness score (quality per dollar) to find the best value configuration

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Same inputs for both
# - Quality and cost scores
# - Winner recommendation
# - Swappable configurations
