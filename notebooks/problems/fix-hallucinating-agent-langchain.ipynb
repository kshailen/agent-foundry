# %% [markdown]
# # Problem 1: Fix the Hallucinating Agent
#
# **Difficulty:** Easy | **Framework:** LangChain
#
# **Categories:** prompt-design
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/fix-hallucinating-agent).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q langchain langchain-openai langchain-community langgraph

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - You may only modify the system prompt
# - The agent must still answer the user's question helpfully
# - No additional tools may be added

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.tools import DuckDuckGoSearchRun

llm = ChatOpenAI(model="gpt-4o-mini")
search = DuckDuckGoSearchRun()

# BUG: This system prompt allows the agent to hallucinate URLs
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful research assistant. Answer questions thoroughly."),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}"),
])

agent = create_tool_calling_agent(llm, [search], prompt)
executor = AgentExecutor(agent=agent, tools=[search])

# Test: Ask something that might trigger hallucinated URLs
result = executor.invoke({"input": "What are the best resources to learn LangChain?"})
print(result["output"])

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Think about what instruction would prevent the agent from guessing URLs
# 2. Explicitly tell the agent what to do when it doesn't have verified information
# 3. Add a constraint like: 'Never fabricate URLs, citations, or links. If you do not have a verified source, say so explicitly.'

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - No fabricated URLs
# - Still answers helpfully
# - Handles unknowns gracefully
