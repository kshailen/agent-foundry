# %% [markdown]
# # Problem 60: Graceful Timeout Handler
#
# **Difficulty:** Easy | **Framework:** CrewAI
#
# **Categories:** error-recovery
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/graceful-timeout-handler).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - You must not remove or disable the slow tool
# - The timeout threshold must be configurable, not hardcoded
# - The agent must return a user-friendly message on timeout
# - Normal tool responses that complete in time must still work

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
import time
from crewai import Agent, Task, Crew
from crewai.tools import tool

@tool
def slow_api_lookup(query: str) -> str:
    """Look up information from an external API."""
    # BUG: This tool takes 30 seconds and the agent has no timeout protection
    time.sleep(30)
    return f"Results for: {query}"

assistant = Agent(
    role="Research Assistant",
    goal="Answer questions using tools",
    backstory="You are a helpful assistant. Use tools to answer questions.",
    tools=[slow_api_lookup],
)

# Test: This will hang for 30 seconds with no feedback
task = Task(
    description="Look up the latest AI news",
    expected_output="Latest AI news results",
    agent=assistant,
)

crew = Crew(agents=[assistant], tasks=[task])
result = crew.kickoff()
print(result)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Python's signal module or threading.Timer can enforce time limits on synchronous calls
# 2. Wrap the tool call in a helper that raises a custom exception after the timeout elapses
# 3. Catch the timeout exception and return a friendly fallback string instead of crashing

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Timeout is enforced
# - Returns friendly message
# - Fast tools still work
