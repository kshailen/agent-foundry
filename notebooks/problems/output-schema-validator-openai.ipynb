# %% [markdown]
# # Problem 67: Output Schema Validator
#
# **Difficulty:** Medium | **Framework:** OpenAI Agents SDK
#
# **Categories:** guardrails
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/output-schema-validator).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q openai-agents

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - The agent's output must be validated against a Pydantic model before being returned
# - Invalid outputs must trigger a re-prompt or a structured error, not a crash
# - The Pydantic schema must not be weakened to match bad outputs

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from agents import Agent, Runner
from pydantic import BaseModel

class ProductReview(BaseModel):
    product_name: str
    rating: int  # 1-5
    summary: str
    pros: list[str]
    cons: list[str]

# BUG: The output is not validated — it may not match the ProductReview schema
agent = Agent(
    name="Review Assistant",
    instructions="You are a product review assistant. Analyze the given product and return a structured JSON review with fields: product_name, rating (1-5), summary, pros (list), cons (list).",
)

result = Runner.run_sync(agent, "Review the Sony WH-1000XM5 headphones")
print(result.final_output)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Define a Pydantic model for the expected output shape and validate the agent's response against it
# 2. If validation fails, re-prompt the LLM with the validation error to get a corrected response
# 3. Use json.loads() to parse the agent's output before passing it to Pydantic

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Output matches Pydantic schema
# - Invalid output is handled
# - All required fields present
# - No unhandled exceptions
