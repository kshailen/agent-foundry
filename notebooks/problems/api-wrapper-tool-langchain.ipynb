# %% [markdown]
# # Problem 18: API Wrapper Tool
#
# **Difficulty:** Easy | **Framework:** LangChain
#
# **Categories:** tool-calling
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/api-wrapper-tool).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q langchain langchain-openai langchain-community langgraph

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - The tool must wrap the GitHub Users API endpoint
# - All HTTP errors must be caught and returned as readable messages
# - The agent must use the tool instead of raw API calls
# - No changes to the agent's core logic besides adding the tool

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain_core.prompts import ChatPromptTemplate
import requests

llm = ChatOpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that looks up GitHub user profiles."),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}"),
])

# BUG: The agent has no tool — it tries to answer from memory or makes raw API calls inline
# TODO: Wrap the GitHub user lookup into a proper tool with error handling

def lookup_github_user(username: str) -> str:
    response = requests.get(f"https://api.github.com/users/{username}")
    data = response.json()
    return str(data)

agent = create_tool_calling_agent(llm, [], prompt)
executor = AgentExecutor(agent=agent, tools=[])

result = executor.invoke({"input": "Tell me about the GitHub user 'octocat'"})
print(result["output"])

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Define a function that takes a username, calls the GitHub API, and returns structured user info
# 2. Wrap the function with the framework's tool decorator so the agent can discover and call it
# 3. Handle non-200 status codes inside the tool so the agent receives a clear error string instead of a traceback

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Tool is registered with the agent
# - Handles API errors gracefully
# - Returns structured user info
