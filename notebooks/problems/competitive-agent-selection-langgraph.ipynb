# %% [markdown]
# # Problem 84: Competitive Agent Selection
#
# **Difficulty:** Hard | **Framework:** LangGraph
#
# **Categories:** multi-agent, evaluation
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/competitive-agent-selection).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q langgraph langchain langchain-openai langchain-community

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - At least three agents must independently solve the same problem
# - A separate judge agent must evaluate all solutions and pick the best
# - The judge must not be one of the competing agents
# - The judge must provide a rationale for its selection

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

llm = ChatOpenAI(model="gpt-4o-mini")

class State(TypedDict):
    problem: str
    solution: str

# BUG: Only one solver node — no competition or judging
# TODO: Add multiple solver nodes and a judge node
def solve(state: State) -> dict:
    prompt = f"Write a Python function to solve: {state['problem']}. Provide clean, efficient code with explanation."
    response = llm.invoke(prompt)
    return {"solution": response.content}

graph = StateGraph(State)
graph.add_node("solve", solve)
graph.add_edge(START, "solve")
graph.add_edge("solve", END)

app = graph.compile()
result = app.invoke({"problem": "Find the longest palindromic substring in a given string", "solution": ""})
print(result["solution"])

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Run all three solver agents in parallel (or sequentially) on the same input
# 2. Collect all outputs, then pass them to the judge agent with clear labels
# 3. Give the judge explicit evaluation criteria (correctness, clarity, completeness) to score against

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Multiple solver agents
# - Judge agent evaluates solutions
# - Judge provides rationale
# - Best solution is selected
