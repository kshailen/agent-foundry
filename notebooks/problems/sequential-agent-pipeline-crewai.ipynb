# %% [markdown]
# # Problem 77: Sequential Agent Pipeline
#
# **Difficulty:** Easy | **Framework:** CrewAI
#
# **Categories:** multi-agent, orchestration
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/sequential-agent-pipeline).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - The researcher agent must run before the writer agent
# - The writer must receive the researcher's output as input
# - You may not merge both roles into a single agent
# - The pipeline must run end-to-end with a single invocation

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from crewai import Agent, Task, Crew
from crewai import LLM

llm = LLM(model="gpt-4o-mini")

researcher = Agent(
    role="Researcher",
    goal="Gather key facts about a given topic",
    backstory="You are a thorough research analyst.",
    llm=llm,
)

writer = Agent(
    role="Writer",
    goal="Write a concise summary from research notes",
    backstory="You are a skilled technical writer.",
    llm=llm,
)

research_task = Task(
    description="Research the latest trends in {topic}",
    expected_output="A list of 5 key findings with brief explanations",
    agent=researcher,
)

write_task = Task(
    description="Write a 200-word summary about {topic}",
    expected_output="A polished summary paragraph",
    agent=writer,
)

# BUG: Both tasks run independently — the writer never sees the research
# TODO: Wire the tasks so the writer receives the researcher's output
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
)

result = crew.kickoff(inputs={"topic": "AI agents"})
print(result)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Capture the researcher's output and pass it as context to the writer
# 2. In CrewAI, use a sequential Process so tasks execute in order with automatic context passing
# 3. In LangChain, chain the two agents using RunnableSequence or call them sequentially in code

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Sequential execution order
# - Research context flows to writer
# - Coherent final summary
