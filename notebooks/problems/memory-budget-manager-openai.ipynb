# %% [markdown]
# # Problem 41: Memory Budget Manager
#
# **Difficulty:** Hard | **Framework:** OpenAI Agents SDK
#
# **Categories:** memory, cost-optimization
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/memory-budget-manager).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q openai-agents

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - Total memory must stay under a configurable token budget
# - Eviction must be based on relevance or recency, not random
# - The budget check and eviction must happen automatically before each call
# - High-importance items should be protected from eviction

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from agents import Agent, Runner

# BUG: Memory grows without bound — no budget enforcement
memory_items = []

agent = Agent(
    name="Assistant",
    instructions="You are a helpful assistant.",
)

def add_memory(item: str):
    memory_items.append(item)

for i in range(30):
    topic = f"Tell me an interesting fact about country number {i + 1} in the world."
    add_memory(f"User: {topic}")
    memory_block = "\n".join(memory_items)
    prompt = f"Memory:\n{memory_block}\n\nRespond to: {topic}"
    result = Runner.run_sync(agent, prompt)
    add_memory(f"Assistant: {result.final_output[:200]}")
    print(f"Turn {i + 1} ({len(memory_items)} items): {result.final_output[:60]}...")

print(f"\nTotal memory items: {len(memory_items)}")
total_chars = sum(len(item) for item in memory_items)
print(f"Total characters in memory: {total_chars}")

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Track an approximate token count for each memory item using a simple word-count heuristic (1 token ≈ 0.75 words)
# 2. Score each item by combining recency and access frequency, then evict the lowest-scoring items first
# 3. Allow marking certain items as 'pinned' so they are never evicted regardless of budget pressure

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Token budget enforced
# - Eviction is relevance-based
# - Important items protected
# - Budget enforced automatically
