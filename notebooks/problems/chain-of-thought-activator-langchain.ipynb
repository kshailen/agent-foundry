# %% [markdown]
# # Problem 5: Chain-of-Thought Activator
#
# **Difficulty:** Easy | **Framework:** LangChain
#
# **Categories:** prompt-design
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-pi.vercel.app/problems/chain-of-thought-activator).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q langchain langchain-openai langchain-community langgraph

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - You may only modify the system prompt
# - The agent must show its reasoning before the final answer
# - No external calculator tools may be added

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini")

# BUG: This prompt encourages direct answers without showing reasoning steps
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a math assistant. Give the answer to the user's math problem. Be concise — just state the final number."),
    ("human", "{input}"),
])

chain = prompt | llm

# Test: multi-step word problem that requires intermediate calculations
result = chain.invoke({
    "input": "A store sells notebooks for $4 each. Sarah buys 3 notebooks and pays with a $20 bill. She then buys 2 pens at $1.50 each. How much money does she have left?"
})
print(result.content)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Ask the model to think step by step and show each intermediate calculation
# 2. Include a worked example in the prompt so the model sees the expected reasoning format
# 3. Instruct the model to separate its reasoning steps from the final answer with a clear marker

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Correct final answer
# - Reasoning steps shown
# - Intermediate calculations visible
