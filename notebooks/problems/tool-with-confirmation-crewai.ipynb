# %% [markdown]
# # Problem 19: Tool with Confirmation
#
# **Difficulty:** Easy | **Framework:** CrewAI
#
# **Categories:** tool-calling, guardrails
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/tool-with-confirmation).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q crewai crewai-tools

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - The send_email tool must not execute without explicit user confirmation
# - The confirmation step must show the recipient and subject before proceeding
# - The agent must handle both 'yes' and 'no' confirmation responses
# - No emails should be sent if the user declines

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from crewai import Agent, Task, Crew, Process
from crewai.tools import tool

# BUG: This tool sends the email immediately with no confirmation
# TODO: Add a confirmation step so the user can review before sending

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an email to the specified recipient."""
    print(f"EMAIL SENT to {to}: {subject}")
    return f"Email sent successfully to {to} with subject '{subject}'"

email_agent = Agent(
    role="Email Assistant",
    goal="Help users compose and send emails.",
    backstory="You are an assistant that helps users send emails. When asked to send an email, do it immediately.",
    tools=[send_email],
)

task = Task(
    description="Send an email to bob@example.com with subject 'Meeting Tomorrow' and body 'Hi Bob, can we meet at 3pm?'",
    expected_output="Confirmation that the email was sent successfully.",
    agent=email_agent,
)

crew = Crew(agents=[email_agent], tasks=[task], process=Process.sequential)
result = crew.kickoff()
print(result)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Split the flow into two steps: a preview step that shows what will be sent, and a send step that executes only after approval
# 2. Consider using a human-in-the-loop pattern where the agent pauses and asks the user to confirm before calling the side-effect tool
# 3. You can implement confirmation as a separate tool that checks user intent, or by adding a confirmation parameter to the existing tool

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - No automatic sending
# - Preview shown before sending
# - Decline is respected
