# %% [markdown]
# # Problem 97: Caching Layer
#
# **Difficulty:** Medium | **Framework:** OpenAI Agents SDK
#
# **Categories:** cost-optimization
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/caching-layer).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q openai-agents

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - Semantically similar queries must return cached responses without calling the LLM
# - The cache must store and retrieve based on semantic similarity, not exact string match
# - Cache hits must be significantly faster than LLM calls and incur zero token cost
# - The cache must have a configurable TTL or max size to prevent unbounded growth

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from agents import Agent, Runner
import time

agent = Agent(
    name="Customer Support",
    instructions="You are a helpful customer support agent. Answer concisely.",
    model="gpt-4o-mini",
)

# BUG: Every query calls the LLM, even repeated or near-identical questions
# TODO: Add a caching layer that serves cached responses for similar queries
questions = [
    "What is your return policy?",
    "How do I return an item?",
    "What's your policy on returns?",
    "Do you offer free shipping?",
    "Is shipping free?",
    "What is your return policy?",
    "Do you ship for free?",
    "How can I return a product?",
]
for q in questions:
    start = time.time()
    result = Runner.run_sync(agent, q)
    elapsed = time.time() - start
    print(f"Q: {q}\nA: [{elapsed:.2f}s] {result.final_output}\n")

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Use an embedding model to convert queries to vectors, then check cosine similarity against cached query vectors before calling the LLM
# 2. Set a similarity threshold (e.g., 0.95) — above it, return the cached response; below it, call the LLM and cache the new result
# 3. LangChain has built-in caching support via SQLiteCache or InMemoryCache for exact-match caching, but semantic caching requires embeddings

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Cache hit on similar queries
# - Faster on cache hit
# - Zero token cost on hit
# - Bounded cache size
