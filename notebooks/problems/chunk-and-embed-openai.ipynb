# %% [markdown]
# # Problem 47: Chunk and Embed
#
# **Difficulty:** Easy | **Framework:** OpenAI Agents SDK
#
# **Categories:** rag
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/chunk-and-embed).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q openai-agents

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - The document must be split into chunks before embedding
# - Chunk size must not exceed 500 characters
# - Embeddings must be stored in a vector store for retrieval
# - The final answer must come from retrieved chunks, not the full document

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from agents import Agent, Runner

# A 50-page document (simulated as a long string)
long_document = "CHAPTER 1: INTRODUCTION\n" + "\n".join(
    [f"Section 1.{i}: This section covers topic {i} in great detail. " * 20 for i in range(1, 51)]
)

# BUG: Stuffing the entire document into the prompt — exceeds context window
agent = Agent(
    name="Document Q&A",
    instructions=f"Answer the user's question based on this document:\n\n{long_document}",
)

result = Runner.run_sync(agent, "What does section 1.25 cover?")
print(result.final_output)

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Use a text splitter to break the document into overlapping chunks of manageable size
# 2. Create embeddings for each chunk and store them in a vector store like FAISS or Chroma
# 3. Retrieve only the most relevant chunks for the question instead of stuffing everything into the prompt

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - Splits document into chunks
# - Creates and stores embeddings
# - Retrieves relevant chunks
# - Answers correctly from chunks
