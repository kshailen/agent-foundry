# %% [markdown]
# # Problem 33: Context Window Truncation
#
# **Difficulty:** Easy | **Framework:** LangChain
#
# **Categories:** memory, cost-optimization
#
# This notebook accompanies [Agent Foundry](https://agent-foundry-theta.vercel.app/problems/context-window-truncation).

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q langchain langchain-openai langchain-community langgraph

# %% [markdown]
# ## 2. Set Up Your API Key

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 3. Constraints
#
# - The sliding window must keep the most recent N turns
# - The system message must always be preserved regardless of truncation
# - You may not increase the model's context window limit
# - The agent must remain functional after truncation

# %% [markdown]
# ## 4. Starter Code (has a bug — fix it!)
#
# The code below has an intentional issue. Read the problem description and fix it.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# BUG: History grows without bound — crashes or loses coherence on long conversations
history = [SystemMessage(content="You are a helpful assistant.")]

def chat(user_input: str) -> str:
    history.append(HumanMessage(content=user_input))
    response = llm.invoke(history)
    history.append(response)
    return response.content

# Simulate a 50-turn conversation
for i in range(50):
    reply = chat(f"Tell me fact number {i + 1} about space exploration.")
    print(f"Turn {i + 1}: {reply[:80]}...")

# By turn 50 the context may exceed limits or degrade
print(f"\nTotal messages in history: {len(history)}")

# %% [markdown]
# ## 5. Your Solution
#
# Modify the code above or write your fixed version below.

# %%
# Write your solution here

# %% [markdown]
# ## 6. Hints
#
# 1. Count the number of messages and slice the list to keep only the most recent ones
# 2. Always keep the system message at position 0 and truncate only user/assistant pairs
# 3. Implement a helper function that trims the history before each call, preserving the system prompt and the last N exchanges

# %% [markdown]
# ## 7. Evaluation Criteria
#
# Check your solution against these criteria:
#
# - History stays bounded
# - System message preserved
# - Recent context retained
